# %%
import seaborn as sb

print(sb.get_dataset_names())

planets_data = sb.load_dataset("flights")
print(planets_data.head())

sb.set_theme('talk','darkgrid')
# sb.scatterplot(planets_data, x="year", y="passengers")
# sb.lineplot(planets_data, x="year", y="passengers")
sb.barplot(data=planets_data, x="year", y="passengers")
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# <Axes: xlabel='year', ylabel='passengers'>
